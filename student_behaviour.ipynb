# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_csv('data/Student_Behaviour.csv')
df.head(3)
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
#
#    12th Mark  college mark      hobbies daily studing time prefer to study in  \
# 0       65.0          80.0  Video Games      0 - 30 minute            Morning
# 1       80.0          70.0       Cinema     30 - 60 minute            Morning
# 2       61.0          55.0       Cinema         1 - 2 Hour            Anytime
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
# 2               13000                      Yes
#
#   willingness to pursue a career based on their degree   social medai & video  \
# ...

# %%
df['willingness to pursue a career based on their degree  ']

# %%
df.rename(columns={'willingness to pursue a career based on their degree  ': 'willingness to pursue a career based on their degree(%)'}, inplace=True)

# %%
df.head(3)
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
#
#    12th Mark  college mark      hobbies daily studing time prefer to study in  \
# 0       65.0          80.0  Video Games      0 - 30 minute            Morning
# 1       80.0          70.0       Cinema     30 - 60 minute            Morning
# 2       61.0          55.0       Cinema         1 - 2 Hour            Anytime
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
# 2               13000                      Yes
#
#   willingness to pursue a career based on their degree(%)  \
# 0                                                50%
# ...

# %%
df['willingness to pursue a career based on their degree(%)'].unique()
# Out:
# array(['50%', '75%', '25%', '100%', '0%'], dtype=object)

# %%
for i in df['willingness to pursue a career based on their degree(%)'].unique():
    print(df[df['willingness to pursue a career based on their degree(%)'] == i]['willingness to pursue a career based on their degree(%)'])
# Out:
# 0      50%
# 2      50%
# 3      50%
# 5      50%
# 7      50%
#       ...
# 206    50%
# 207    50%
# 222    50%
# 229    50%
# 231    50%
# Name: willingness to pursue a career based on their degree(%), Length: 61, dtype: object
# 1      75%
# 6      75%
# 8      75%
# 9      75%
# 10     75%
#       ...
# 225    75%
# 228    75%
# 230    75%
# 232    75%
# 233    75%
# Name: willingness to pursue a career based on their degree(%), Length: 114, dtype: object
# 4      25%
# 39     25%
# 45     25%
# 63     25%
# 70     25%
# 72     25%
# 86     25%
# 98     25%
# 142    25%
# 145    25%
# 159    25%
# 160    25%
# 181    25%
# 226    25%
# Name: willingness to pursue a career based on their degree(%), dtype: object
# 17     100%
# 18     100%
# 19     100%
# 27     100%
# 28     100%
# 31     100%
# 36     100%
# 37     100%
# 43     100%
# 51     100%
# 52     100%
# 53     100%
# 56     100%
# 58     100%
# 62     100%
# 76     100%
# 83     100%
# 84     100%
# 90     100%
# ...

# %%
for i in df['willingness to pursue a career based on their degree(%)'].unique():
    df.loc[df['willingness to pursue a career based on their degree(%)'] == i, 'willingness to pursue a career based on their degree(%)'] = i[:-1]

# %%
df.head(3)
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       69.5
#
#    12th Mark  college mark      hobbies daily studing time prefer to study in  \
# 0       65.0          80.0  Video Games      0 - 30 minute            Morning
# 1       80.0          70.0       Cinema     30 - 60 minute            Morning
# 2       61.0          55.0       Cinema         1 - 2 Hour            Anytime
#
#    salary expectation Do you like your degree?  \
# 0               40000                       No
# 1               15000                      Yes
# 2               13000                      Yes
#
#   willingness to pursue a career based on their degree(%)  \
# 0                                                 50
# ...

# %%
df['willingness to pursue a career based on their degree(%)'].unique()
# Out:
# array(['50', '75', '25', '100', '0'], dtype=object)

# %%
df['willingness to pursue a career based on their degree(%)'] = df['willingness to pursue a career based on their degree(%)'].astype('int64')

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

X_new = pd.DataFrame()
for name in df.columns:
    if df[name].dtype == object:
        if df[name].nunique() >= 3:
            ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])], 
                                    remainder= 'passthrough')
            col_names = sorted(df[name].unique())
            for i in range(len(col_names)):
                col_names[i] = f'{name}: {col_names[i]}'
            X_new[col_names] = ct.fit_transform(df[name].to_frame())

        else:
            label_encoder = LabelEncoder()
            X_new[name] = label_encoder.fit_transform(df[name])

    else:
        X_new[name] = df[name]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5912\639832438.py in ?()
#       9 for name in df.columns:
#      10     if df[name].dtype == object:
#      11         if df[name].nunique() >= 3:
#      12             ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])],
# ---> 13                                     remainder= 'passthrough')
#      14             col_names = sorted(df[name].unique())
#      15             for i in range(len(col_names)):
#      16                 col_names[i] = f'{name}: {col_names[i]}'
#
# c:\Users\405\anaconda3\envs\app_dash\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3964
#    3965         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    3966             self._setitem_frame(key, value)
#    3967         elif isinstance(key, (Series, np.ndarray, list, Index)):
# ...

# %%
X_new = pd.DataFrame()
for name in df.columns:
    if df[name].dtype == object:
        if df[name].nunique() >= 3:
            ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])], 
                                    remainder= 'passthrough')
            col_names = [None] * len(df[name].unique())
            for i, unique_value in enumerate(sorted(df[name].unique())):
                col_names[i] = f'{name}: {unique_value}'
            X_new[col_names] = ct.fit_transform(df[name].to_frame())

        else:
            label_encoder = LabelEncoder()
            X_new[name] = label_encoder.fit_transform(df[name])

    else:
        X_new[name] = df[name]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5912\2801614448.py in ?()
#       6             ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])],
#       7                                     remainder= 'passthrough')
#       8             col_names = [None] * len(df[name].unique())
#       9             for i, unique_value in enumerate(sorted(df[name].unique())):
# ---> 10                 col_names[i] = f'{name}: {unique_value}'
#      11             X_new[col_names] = ct.fit_transform(df[name].to_frame())
#      12
#      13         else:
#
# c:\Users\405\anaconda3\envs\app_dash\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3964
#    3965         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    3966             self._setitem_frame(key, value)
# ...

# %%
X_new = pd.DataFrame()
for name in df.columns:
    if df[name].dtype == object:
        if df[name].nunique() >= 3:
            ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])], 
                                    remainder= 'passthrough')
            col_names = [f'{name}: {unique_value}' for unique_value in sorted(df[name].unique())]
            transformed_data = ct.fit_transform(df[name].to_frame())
            X_new[col_names] = pd.DataFrame(transformed_data, columns=col_names)

        else:
            label_encoder = LabelEncoder()
            X_new[name] = label_encoder.fit_transform(df[name])

    else:
        X_new[name] = df[name]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 9
#       7     col_names = [f'{name}: {unique_value}' for unique_value in sorted(df[name].unique())]
#       8     transformed_data = ct.fit_transform(df[name].to_frame())
# ----> 9     X_new[col_names] = pd.DataFrame(transformed_data, columns=col_names)
#      11 else:
#      12     label_encoder = LabelEncoder()
#
# File c:\Users\405\anaconda3\envs\app_dash\lib\site-packages\pandas\core\frame.py:762, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     754         mgr = arrays_to_mgr(
#     755             arrays,
#     756             columns,
#    (...)
#     759             typ=manager,
#     760         )
#     761     else:
# --> 762         mgr = ndarray_to_mgr(
#     763             data,
#     764             index,
#     765             columns,
#     766             dtype=dtype,
# ...

# %%
X_new = pd.DataFrame()
for name in df.columns: # 각 컬럼을 name으로 받아서 반복
    if df[name].dtype == object: # 문자열로 이뤄졌을 경우 데이터 종류 수 확인
        if df[name].nunique() >= 3: # 원핫 인코딩
            ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])], 
                                    remainder= 'passthrough')
            col_names = sorted(df[name].unique())
            X_new[col_names] = ct.fit_transform( df[name].to_frame())

        else: # 레이블 인코딩
            label_encoder = LabelEncoder()
            X_new[name] = label_encoder.fit_transform(df[name])

    # 숫자 데이터일 때 처리는 여기서
    else:
        X_new[name] = df[name]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5912\2627526083.py in ?()
#       4     if df[name].dtype == object: # 문자열로 이뤄졌을 경우 데이터 종류 수 확인
#       5         if df[name].nunique() >= 3: # 원핫 인코딩
#       6             ct = ColumnTransformer([('encoder', OneHotEncoder(), [0])],
#       7                                     remainder= 'passthrough')
# ----> 8             col_names = sorted(df[name].unique())
#       9             X_new[col_names] = ct.fit_transform( df[name].to_frame())
#      10
#      11         else: # 레이블 인코딩
#
# c:\Users\405\anaconda3\envs\app_dash\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3964
#    3965         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    3966             self._setitem_frame(key, value)
# ...

# %%
# Department 종류 4개
# hobbies 4개
# 하루 공부시간을 6개로 나눔.
# 0~30, 30~60, 1~2, 2~3, 3~4, 4이상
# 자기 학과로 취업할건지 25% 단위로 5종
# 소셜미디어, 비디오 시간 0, ~30, ~60, ~1.5, ~2, 2이상으로 6종
# 공부시간 아무때나, 아침, 저녁 3개
# 등교시간(왕복) 30분 단위로 3시간 이상까지 7종류
# 스트레스레벨 4종류
# 자금레벨 4종류
# 알바 두종류

# %%
df.to_csv('Student_Behaviour2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 19 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   Certification Course                                     234 non-null    object
#  1   Gender                                                   234 non-null    object
#  2   Department                                               234 non-null    object
#  3   Height(CM)                                               234 non-null    float64
#  4   Weight(KG)                                               234 non-null    float64
#  5   10th Mark                                                234 non-null    float64
#  6   12th Mark                                                234 non-null    float64
#  7   college mark                                             234 non-null    float64
# ...
